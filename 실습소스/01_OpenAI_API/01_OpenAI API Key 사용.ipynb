# %% [markdown]
# ## OpenAI API 사용

# %%
# !pip install openai
# !pip install --upgrade openai

# %%
import openai
print(openai.__version__)  # 2.37.0
# Out:
# 2.37.0

# %%
from openai import OpenAI
# OpenAI API Key
API_KEY = 'YOUR_API_KEY'

client = OpenAI(api_key=API_KEY)
print(type(client))
# print(API_KEY)
# Out:
# <class 'openai.OpenAI'>

# %%
# API 호출 질의 요청
completion = client.chat.completions.create(
    model = "gpt-4o-mini",  # 모델이름
    messages = [ {"role":"user", "content":"너는 누구니?"} ]
)    

# 응답 출력
# print(completion)
print(completion.choices[0].message.content)
# Out:
# 안녕하세요! 저는 AI 언어 모델로, 다양한 질문에 답하고 정보를 제공하는 역할을 합니다. 궁금한 점이 있으면 언제든지 물어보세요!

# %%
# API 호출 질의 요청
completion = client.chat.completions.create(
    model = "gpt-4o-mini",  # 모델이름
    messages = [ {"role":"user", "content":"오늘 날씨 알려줘?"} ]
)    

# 응답 출력
# print(completion)
print(completion.choices[0].message.content)
# Out:
# 죄송하지만, 실시간 날씨 정보를 제공할 수는 없습니다. 그러나 웹사이트나 날씨 앱을 통해 현재 날씨를 쉽게 확인하실 수 있습니다. 필요한 지역의 날씨를 확인하고 싶으시면 말씀해 주세요. 도움이 될 수 있는 다른 방법을 찾아보겠습니다!

# %%
# API 호출 질의 요청
completion = client.chat.completions.create(
    model = "gpt-4o-mini",  # 모델이름
    messages = [ {"role":"user", "content":"2020년 도쿄 올림픽의 우승국은?"} ]
)    

# 응답 출력

print(completion.choices[0].message.content)
# Out:
# 2020년 도쿄 올림픽은 2021년에 개최되었습니다. 이 대회에서 미국이 메달 집계에서 가장 많은 금메달을 획득하여 우승국이 되었습니다. 미국은 총 39개의 금메달을 포함하여 많은 메달을 따며 전반적으로 가장 성공적인 대회를 치렀습니다.

# %%
# API 호출 질의 요청
completion = client.chat.completions.create(
    model = "gpt-4o-mini",  # 모델이름
    messages = [ {"role":"user", "content":"2024년 파리 올림픽의 우승국은?"} ]
)    

# 응답 출력
print(completion.choices[0].message.content)
# Out:
# 죄송하지만, 2024년 파리 올림픽의 결과에 대한 정보는 제공할 수 없습니다. 제 데이터는 2023년 10월까지의 정보로 제한되어 있으며, 미래의 사건이나 결과에 대한 예측을 할 수 없습니다. 올림픽에 대한 최신 정보를 보려면 공식 올림픽 웹사이트나 뉴스 소스를 참고하시기 바랍니다.

# %%
client = OpenAI(api_key=API_KEY)
model = "gpt-4o-mini"
messages = [ 
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content":"하늘은 왜 파란가요?"} ]

completion = client.chat.completions.create(model=model,messages=messages)
print(completion.choices[0].message.content)
# Out:
# 하늘이 파란 이유는 대기 중의 산란현상 때문입니다. 태양에서 오는 빛은 여러 색깔로 이루어져 있는데, 그중 파란색 빛은 짧은 파장을 가지고 있어 대기 중의 분자들과 더 많이 산란됩니다.
#
# 대기 속의 산소와 질소 분자가 태양빛을 산란시키면서 파란색 빛이 주로 널리 퍼지는 것입니다. 이 현상을 '레이리 산란'이라고 하며, 태양이 높이 떠 있을 때에는 하늘이 푸르게 보이고, 해가 지거나 떠 있을 때는 붉은 색 또는 주황색으로 보이는 것은 긴 파장인 붉은 빛이 산란되지 않고 직진하기 때문입니다.
#
# 결과적으로 낮 동안에 하늘은 대부분 파란색으로 보입니다.

# %%
# Claude API 사용법
# https://console.anthropic.com/
# ! pip install anthropic

import anthropic

# Claude API 키 설정
API_KEY2 = "YOUR API KEY"
client = anthropic.Anthropic(api_key=API_KEY2)

# API 호출
response = client.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=100,
    messages=[ {"role":"user", "content":"안녕하세요!"}]    
)

# 응답 출력
print(response.content[0].text)

# %%
print(response)

# %% [markdown]
# #### OpenAI API Key를 파이썬소스 외부에 넣어 사용하기

# %%
# ! pip install python-dotenv

# %%
from dotenv import load_dotenv
import os

# .env 파일 불러오기
load_dotenv("C:/env/.env")

# 환경 변수 가져오기
API_KEY = os.getenv("OPENAI_API_KEY")
# print(API_KEY)

# %%
from openai import OpenAI
client = OpenAI(api_key=API_KEY)
model = "gpt-4o-mini"
messages = [ 
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content":"하늘은 왜 파란가요?"} ]

completion = client.chat.completions.create(model=model,messages=messages)
print(completion.choices[0].message.content)
# Out:
# 하늘이 파란 이유는 주로 대기 중에서 빛이 산란되는 현상과 관련이 있습니다. 태양빛은 여러 색의 빛이 혼합된 형태로, 각각의 색은 서로 다른 파장을 가지고 있습니다. 이 중 파란색 빛은 파장이 짧기 때문에 대기 중의 기체 분자와 더 많이 상호작용하게 됩니다.
#
# 대기 중의 산소와 질소 같은 기체 분자들이 태양빛을 산란시키면서, 파란색 빛이 다른 색보다 더 많이 퍼지게 됩니다. 이러한 현상을 레일리 산란(Rayleigh scattering)이라고 합니다. 그래서 우리가 하늘을 바라볼 때 파란색이 더 많이 나타나게 되어 하늘이 파랗게 보이는 것입니다.
#
# 또한, 해가 떠있는 낮 동안 하늘은 주로 파란색으로 보이지만, 해가 지거나 해질녘에는 태양의 위치에 따라 보이는 색이 다르게 나타나기도 합니다. 이때는 빨간색이나 주황색으로 변할 수 있습니다.

# %%
client = OpenAI(api_key=API_KEY)
model = "gpt-4o-mini"
messages = [ 
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content":"오늘은 며칠인가요?"} ]

completion = client.chat.completions.create(model=model,messages=messages)
print(completion.choices[0].message.content)
# Out:
# 오늘은 2023년 10월 23일입니다. 다른 도움이 필요하시면 말씀해 주세요!

# %%
# 프롬프트 구성 요소 설정
instruction = "다음 글을 요약해 주세요:"
context = "이 글은 기후 변화가 해양 생물에 미치는 영향에 대한 과학적 논문에서 발췌한 것입니다."
input_data = "연구에 따르면, 해수 온도의 상승이 산호초 개체수의 급격한 감소를 초래했다고 합니다."
output_directive = "요약은 간결하게 작성하고, 일반 대중이 이해할 수 있는 형태로 작성해 주세요."

# 프롬프트 결합
prompt = f"{instruction}\n\n문맥: {context}\n\n텍스트: {input_data}\n\n{output_directive}"

# %%
print(prompt)
# Out:
# 다음 글을 요약해 주세요:
#
# 문맥: 이 글은 기후 변화가 해양 생물에 미치는 영향에 대한 과학적 논문에서 발췌한 것입니다.
#
# 텍스트: 연구에 따르면, 해수 온도의 상승이 산호초 개체수의 급격한 감소를 초래했다고 합니다.
#
# 요약은 간결하게 작성하고, 일반 대중이 이해할 수 있는 형태로 작성해 주세요.

# %%
client = OpenAI(api_key=API_KEY)
model = "gpt-4o-mini"
messages = [ {"role": "user", "content":prompt} ]

completion = client.chat.completions.create(model=model,messages=messages)
print(completion.choices[0].message.content)
# Out:
# 연구에 따르면, 해수 온도가 높아지면서 산호초 개체수가 급격히 감소하고 있습니다.
